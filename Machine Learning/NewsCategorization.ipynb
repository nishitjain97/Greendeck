# %% [markdown]
# ## News Categorization

# %% [markdown]
# Using dataset from huffington post

# %%
"""
    Import required modules
"""
import json
import pandas as pd
import numpy as np
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from sklearn import model_selection, naive_bayes, metrics, preprocessing, svm, decomposition, ensemble, linear_model
from random import shuffle
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ### 1. Load dataset
# Load and structure dataset into usable form

# %%
"""
    LOADS DATASET
    We have chosen Pandas Dataframe as it is easy to visualize and good for data analysis
"""
def load_dataset(filename):
    dataset = pd.read_json(open(filename), lines=True) # lines=True for file containing multiple JSON objects
    return dataset

# %%
filename = 'News_Category_Dataset.json'
dataset = load_dataset(filename)

# %% [markdown]
# ### 2. Pre-process dataset
# ##### 2.1 Get details of dataset.

# %%
dataset.shape
# Out:
# (124989, 6)

# %%
dataset.columns
# Out:
# Index(['authors', 'category', 'date', 'headline', 'link', 'short_description'], dtype='object')

# %%
dataset.head()
# Out:
#            authors       category       date  \
# 0  Melissa Jeltsen          CRIME 2018-05-26
# 1    Andy McDonald  ENTERTAINMENT 2018-05-26
# 2       Ron Dicker  ENTERTAINMENT 2018-05-26
# 3       Ron Dicker  ENTERTAINMENT 2018-05-26
# 4       Ron Dicker  ENTERTAINMENT 2018-05-26
#
#                                             headline  \
# 0  There Were 2 Mass Shootings In Texas Last Week...
# 1  Will Smith Joins Diplo And Nicky Jam For The 2...
# 2    Hugh Grant Marries For The First Time At Age 57
# 3  Jim Carrey Blasts 'Castrato' Adam Schiff And D...
# 4  Julianna Margulies Uses Donald Trump Poop Bags...
#
#                                                 link  \
# 0  https://www.huffingtonpost.com/entry/texas-ama...
# 1  https://www.huffingtonpost.com/entry/will-smit...
# 2  https://www.huffingtonpost.com/entry/hugh-gran...
# 3  https://www.huffingtonpost.com/entry/jim-carre...
# 4  https://www.huffingtonpost.com/entry/julianna-...
#
#                                    short_description
# 0  She left her husband. He killed their children...
# 1                           Of course it has a song.
# 2  The actor and his longtime girlfriend Anna Ebe...
# 3  The actor gives Dems an ass-kicking for not fi...
# 4  The "Dietland" actress said using the bags is ...

# %% [markdown]
# ##### 2.2 Drop irrelavant features

# %%
# Date and link can be considered irrelavant for our needs
dataset.drop(['date', 'link'], axis=1, inplace=True)

# %%
dataset.shape
# Out:
# (124989, 4)

# %%
# Check importance of author name to category
pd.crosstab(dataset['authors'], dataset['category'])
# Out:
# category                                            ARTS  ARTS & CULTURE  \
# authors
#                                                       19              32
#  Bill Bigelow, ContributorRethinking Schools cu...     0               0
#  Bustle, ContributorNews, entertainment, lifest...     0               0
#  Cristian Farias, Elise Foley, and Willa Frej          0               0
#  Jamie Walker, ContributorCEO and Founder of Sw...     0               0
#  Josh Horwitz, ContributorExecutive Director, C...     0               0
#  Logan (Mehl-Laituri) Isaac, ContributorAuthor ...     0               0
# #DoctorsSpeakOut, Contributor#DoctorsSpeakOut i...     0               0
# 'The Koch Sisters', ContributorSo not related t...     0               0
# 10,000 Small Businesses Program, ContributorAn ...     0               0
# 1in20, ContributorVisual stories to destigmatiz...     0               0
# 24/7 Wall St., ContributorSpecial Report               0               0
# 2BoomerBabes, ContributorKathy Bernard and Barb...     0               0
# 2morrowknight, ContributorBestselling Author of...     0               0
# 40 Percent and Rising, ContributorLeading the P...     0               0
# A View From The United Nations, ContributorSeni...     0               0
# A. Ananthalakshmi, Reuters                             0               0
# A. B. Wilkinson, ContributorAssistant Professor...     0               0
# A. Lynn, ContributorFeminist, cinephile, and no...     0               0
# A. Siegel, ContributorEnergy, Environmental Blo...     0               0
# A. Townsend Peterson, ContributorUniversity Dis...     0               0
# A. Trevor Thrall, ContributorSenior Fellow at t...     0               0
# A.C. Thompson and Robert Faturechi, ProPublica,...     0               0
# A.C. Thompson, ProPublica                              0               0
# A.J. Condeelis, ContributorWriter, researcher, ...     0               0
# A.J. Walkley, ContributorAuthor of Vuto & Queer...     0               0
# A.T. McWilliams, Guest WriterGuest Writer              0               0
# AALICIA RANCILIO, Associated Press, Associated ...     0               0
# ABDOULIE JOHN, AP                                      0               0
# ABDULLAH SHARIF, ContributorAuthor and Former D...     0               0
# ...                                                  ...             ...
# Zorianna Kit, ContributorEntertainment journali...     0               0
# Zoë B, ContributorFounder of the Simple Life St...     0               0
# Zoë Triska                                             0               0
# Zsofi McMullin, ContributorWriter                      0               0
# Zubin Sharma, ContributorFounder, Project Poten...     0               0
# Zuhour Mahmoud, Syria Deeply                           0               0
# a.j.k. o'donnell, Contributoraward-winning acti...     0               0
# beverly iseghohi, ContributorPublic Affairs Pro...     0               0
# by Luigi F. di Biagio, La Dolce Vita                   0               0
# charles easley, ContributorI explore, race, cla...     0               0
# davidji, Contributorglobally recognized mindbod...     0               0
# hanna arc, ContributorIndependent Journalist & ...     0               0
# iMFdirect, ContributoriMFdirect features views ...     0               0
# ilona saari, ContributorNovelist, Essayist and ...     0               0
# j.frede, ContributorMultidisciplinary artist ba...     2               0
# j.n. salters, ContributorBlack feminist writer ...     0               0
# justin adkins, ContributorRevolutionary trans* ...     0               0
# meQuilibrium, ContributorPersonalized Stress Ma...     0               0
# ngrid Melander and Sudip Kar-Gupta, Reuters            0               0
# offMetro.com, ContributorGet Out of Town, Car O...     0               0
# oni Clarke and Ransdell Pierson, Reuters               0               0
# ric drasin, ContributorCreator, Iconic Gold's g...     0               0
# simon confino, ContributorFounder Director We-Q...     0               0
# trivago, ContributorHotel search site                  0               0
# xoJANE, Contributor                                    0               0
# xxxx, ContributorProfessor Emeritus, Department...     0               0
# yd Zeigler, Outsports                                  0               0
# Éloïse Bouton, ContributorFreelance journalist,...     0               0
# レシピブログ通信, ContributorEveryday fun, lifestyle, a...     0               0
# 딘 베이커, ContributorCo-director, CEPR; author, "R...     0               0
#
# category                                            BLACK VOICES  BUSINESS  \
# authors
#                                                              778       522
#  Bill Bigelow, ContributorRethinking Schools cu...             0         0
#  Bustle, ContributorNews, entertainment, lifest...             0         0
#  Cristian Farias, Elise Foley, and Willa Frej                  0         0
#  Jamie Walker, ContributorCEO and Founder of Sw...             0         0
#  Josh Horwitz, ContributorExecutive Director, C...             0         0
#  Logan (Mehl-Laituri) Isaac, ContributorAuthor ...             0         0
# #DoctorsSpeakOut, Contributor#DoctorsSpeakOut i...             0         0
# 'The Koch Sisters', ContributorSo not related t...             0         0
# 10,000 Small Businesses Program, ContributorAn ...             0         1
# 1in20, ContributorVisual stories to destigmatiz...             0         0
# 24/7 Wall St., ContributorSpecial Report                       0         2
# 2BoomerBabes, ContributorKathy Bernard and Barb...             0         0
# 2morrowknight, ContributorBestselling Author of...             0         1
# 40 Percent and Rising, ContributorLeading the P...             0         0
# A View From The United Nations, ContributorSeni...             0         0
# A. Ananthalakshmi, Reuters                                     0         0
# A. B. Wilkinson, ContributorAssistant Professor...             1         0
# A. Lynn, ContributorFeminist, cinephile, and no...             0         0
# A. Siegel, ContributorEnergy, Environmental Blo...             0         0
# A. Townsend Peterson, ContributorUniversity Dis...             0         0
# A. Trevor Thrall, ContributorSenior Fellow at t...             0         0
# A.C. Thompson and Robert Faturechi, ProPublica,...             0         0
# A.C. Thompson, ProPublica                                      0         0
# A.J. Condeelis, ContributorWriter, researcher, ...             0         0
# A.J. Walkley, ContributorAuthor of Vuto & Queer...             0         0
# A.T. McWilliams, Guest WriterGuest Writer                      1         0
# AALICIA RANCILIO, Associated Press, Associated ...             0         0
# ABDOULIE JOHN, AP                                              0         0
# ABDULLAH SHARIF, ContributorAuthor and Former D...             0         0
# ...                                                          ...       ...
# Zorianna Kit, ContributorEntertainment journali...             0         0
# Zoë B, ContributorFounder of the Simple Life St...             0         0
# Zoë Triska                                                     0         0
# Zsofi McMullin, ContributorWriter                              0         0
# Zubin Sharma, ContributorFounder, Project Poten...             0         0
# Zuhour Mahmoud, Syria Deeply                                   0         0
# a.j.k. o'donnell, Contributoraward-winning acti...             0         0
# beverly iseghohi, ContributorPublic Affairs Pro...             0         0
# by Luigi F. di Biagio, La Dolce Vita                           0         0
# charles easley, ContributorI explore, race, cla...             3         0
# davidji, Contributorglobally recognized mindbod...             0         0
# hanna arc, ContributorIndependent Journalist & ...             1         0
# iMFdirect, ContributoriMFdirect features views ...             0         0
# ilona saari, ContributorNovelist, Essayist and ...             0         0
# j.frede, ContributorMultidisciplinary artist ba...             0         0
# j.n. salters, ContributorBlack feminist writer ...             0         0
# justin adkins, ContributorRevolutionary trans* ...             0         0
# meQuilibrium, ContributorPersonalized Stress Ma...             0         0
# ngrid Melander and Sudip Kar-Gupta, Reuters                    0         0
# offMetro.com, ContributorGet Out of Town, Car O...             0         0
# oni Clarke and Ransdell Pierson, Reuters                       0         0
# ric drasin, ContributorCreator, Iconic Gold's g...             0         0
# simon confino, ContributorFounder Director We-Q...             0         1
# trivago, ContributorHotel search site                          0         0
# xoJANE, Contributor                                            0         0
# xxxx, ContributorProfessor Emeritus, Department...             0         0
# yd Zeigler, Outsports                                          0         0
# Éloïse Bouton, ContributorFreelance journalist,...             0         0
# レシピブログ通信, ContributorEveryday fun, lifestyle, a...             0         0
# 딘 베이커, ContributorCo-director, CEPR; author, "R...             0         8
#
# category                                            COLLEGE  COMEDY  CRIME  \
# authors
#                                                         111      28    741
#  Bill Bigelow, ContributorRethinking Schools cu...        0       0      0
#  Bustle, ContributorNews, entertainment, lifest...        0       0      0
#  Cristian Farias, Elise Foley, and Willa Frej             0       0      0
#  Jamie Walker, ContributorCEO and Founder of Sw...        0       0      0
#  Josh Horwitz, ContributorExecutive Director, C...        0       0      0
#  Logan (Mehl-Laituri) Isaac, ContributorAuthor ...        0       0      0
# #DoctorsSpeakOut, Contributor#DoctorsSpeakOut i...        0       0      0
# 'The Koch Sisters', ContributorSo not related t...        0       0      0
# 10,000 Small Businesses Program, ContributorAn ...        0       0      0
# 1in20, ContributorVisual stories to destigmatiz...        0       0      0
# 24/7 Wall St., ContributorSpecial Report                  0       0      0
# 2BoomerBabes, ContributorKathy Bernard and Barb...        0       0      0
# 2morrowknight, ContributorBestselling Author of...        0       0      0
# 40 Percent and Rising, ContributorLeading the P...        0       0      0
# A View From The United Nations, ContributorSeni...        0       0      0
# A. Ananthalakshmi, Reuters                                0       0      0
# A. B. Wilkinson, ContributorAssistant Professor...        0       0      0
# A. Lynn, ContributorFeminist, cinephile, and no...        0       0      0
# A. Siegel, ContributorEnergy, Environmental Blo...        0       0      0
# A. Townsend Peterson, ContributorUniversity Dis...        0       0      0
# A. Trevor Thrall, ContributorSenior Fellow at t...        0       0      0
# A.C. Thompson and Robert Faturechi, ProPublica,...        0       0      1
# A.C. Thompson, ProPublica                                 0       0      0
# A.J. Condeelis, ContributorWriter, researcher, ...        0       0      0
# A.J. Walkley, ContributorAuthor of Vuto & Queer...        0       0      0
# A.T. McWilliams, Guest WriterGuest Writer                 0       0      0
# AALICIA RANCILIO, Associated Press, Associated ...        0       0      0
# ABDOULIE JOHN, AP                                         0       0      0
# ABDULLAH SHARIF, ContributorAuthor and Former D...        0       0      0
# ...                                                     ...     ...    ...
# Zorianna Kit, ContributorEntertainment journali...        0       0      0
# Zoë B, ContributorFounder of the Simple Life St...        0       0      0
# Zoë Triska                                                0       0      0
# Zsofi McMullin, ContributorWriter                         0       0      0
# Zubin Sharma, ContributorFounder, Project Poten...        0       0      0
# Zuhour Mahmoud, Syria Deeply                              0       0      0
# a.j.k. o'donnell, Contributoraward-winning acti...        0       0      0
# beverly iseghohi, ContributorPublic Affairs Pro...        0       0      0
# by Luigi F. di Biagio, La Dolce Vita                      0       0      0
# charles easley, ContributorI explore, race, cla...        0       0      0
# davidji, Contributorglobally recognized mindbod...        0       0      0
# hanna arc, ContributorIndependent Journalist & ...        0       0      0
# iMFdirect, ContributoriMFdirect features views ...        0       0      0
# ilona saari, ContributorNovelist, Essayist and ...        0       0      0
# j.frede, ContributorMultidisciplinary artist ba...        0       0      0
# j.n. salters, ContributorBlack feminist writer ...        0       0      0
# justin adkins, ContributorRevolutionary trans* ...        0       0      0
# meQuilibrium, ContributorPersonalized Stress Ma...        0       0      0
# ngrid Melander and Sudip Kar-Gupta, Reuters               0       0      0
# offMetro.com, ContributorGet Out of Town, Car O...        0       0      0
# oni Clarke and Ransdell Pierson, Reuters                  0       0      0
# ric drasin, ContributorCreator, Iconic Gold's g...        0       0      0
# simon confino, ContributorFounder Director We-Q...        0       0      0
# trivago, ContributorHotel search site                     0       0      0
# xoJANE, Contributor                                       0       0      0
# xxxx, ContributorProfessor Emeritus, Department...        0       0      0
# yd Zeigler, Outsports                                     0       0      0
# Éloïse Bouton, ContributorFreelance journalist,...        0       0      0
# レシピブログ通信, ContributorEveryday fun, lifestyle, a...        0       0      0
# 딘 베이커, ContributorCo-director, CEPR; author, "R...        0       0      0
#
# category                                            EDUCATION  ENTERTAINMENT  \
# authors
#                                                             7            950
#  Bill Bigelow, ContributorRethinking Schools cu...          0              0
#  Bustle, ContributorNews, entertainment, lifest...          0              0
#  Cristian Farias, Elise Foley, and Willa Frej               0              0
#  Jamie Walker, ContributorCEO and Founder of Sw...          0              0
#  Josh Horwitz, ContributorExecutive Director, C...          0              0
#  Logan (Mehl-Laituri) Isaac, ContributorAuthor ...          0              0
# #DoctorsSpeakOut, Contributor#DoctorsSpeakOut i...          0              0
# 'The Koch Sisters', ContributorSo not related t...          0              0
# 10,000 Small Businesses Program, ContributorAn ...          0              0
# 1in20, ContributorVisual stories to destigmatiz...          0              0
# 24/7 Wall St., ContributorSpecial Report                    0              0
# 2BoomerBabes, ContributorKathy Bernard and Barb...          0              1
# 2morrowknight, ContributorBestselling Author of...          0              0
# 40 Percent and Rising, ContributorLeading the P...          0              0
# A View From The United Nations, ContributorSeni...          0              0
# A. Ananthalakshmi, Reuters                                  0              0
# A. B. Wilkinson, ContributorAssistant Professor...          0              0
# A. Lynn, ContributorFeminist, cinephile, and no...          0              0
# A. Siegel, ContributorEnergy, Environmental Blo...          0              0
# A. Townsend Peterson, ContributorUniversity Dis...          0              0
# A. Trevor Thrall, ContributorSenior Fellow at t...          0              0
# A.C. Thompson and Robert Faturechi, ProPublica,...          0              0
# A.C. Thompson, ProPublica                                   0              0
# A.J. Condeelis, ContributorWriter, researcher, ...          0              0
# A.J. Walkley, ContributorAuthor of Vuto & Queer...          0              0
# A.T. McWilliams, Guest WriterGuest Writer                   0              0
# AALICIA RANCILIO, Associated Press, Associated ...          0              0
# ABDOULIE JOHN, AP                                           0              0
# ABDULLAH SHARIF, ContributorAuthor and Former D...          0              0
# ...                                                       ...            ...
# Zorianna Kit, ContributorEntertainment journali...          0              1
# Zoë B, ContributorFounder of the Simple Life St...          0              0
# Zoë Triska                                                  0              0
# Zsofi McMullin, ContributorWriter                           0              0
# Zubin Sharma, ContributorFounder, Project Poten...          0              0
# Zuhour Mahmoud, Syria Deeply                                0              0
# a.j.k. o'donnell, Contributoraward-winning acti...          0              0
# beverly iseghohi, ContributorPublic Affairs Pro...          0              0
# by Luigi F. di Biagio, La Dolce Vita                        0              0
# charles easley, ContributorI explore, race, cla...          0              0
# davidji, Contributorglobally recognized mindbod...          0              0
# hanna arc, ContributorIndependent Journalist & ...          0              0
# iMFdirect, ContributoriMFdirect features views ...          0              0
# ilona saari, ContributorNovelist, Essayist and ...          0              1
# j.frede, ContributorMultidisciplinary artist ba...          0              0
# j.n. salters, ContributorBlack feminist writer ...          0              0
# justin adkins, ContributorRevolutionary trans* ...          0              0
# meQuilibrium, ContributorPersonalized Stress Ma...          0              0
# ngrid Melander and Sudip Kar-Gupta, Reuters                 0              0
# offMetro.com, ContributorGet Out of Town, Car O...          0              0
# oni Clarke and Ransdell Pierson, Reuters                    0              0
# ric drasin, ContributorCreator, Iconic Gold's g...          0              0
# simon confino, ContributorFounder Director We-Q...          0              0
# trivago, ContributorHotel search site                       0              0
# xoJANE, Contributor                                         0              0
# xxxx, ContributorProfessor Emeritus, Department...          0              0
# yd Zeigler, Outsports                                       0              0
# Éloïse Bouton, ContributorFreelance journalist,...          0              0
# レシピブログ通信, ContributorEveryday fun, lifestyle, a...          0              0
# 딘 베이커, ContributorCo-director, CEPR; author, "R...          0              0
#
# category                                            FIFTY    ...      SPORTS  \
# authors                                                      ...
#                                                       113    ...         494
#  Bill Bigelow, ContributorRethinking Schools cu...      0    ...           0
#  Bustle, ContributorNews, entertainment, lifest...      0    ...           0
#  Cristian Farias, Elise Foley, and Willa Frej           0    ...           0
#  Jamie Walker, ContributorCEO and Founder of Sw...      0    ...           0
#  Josh Horwitz, ContributorExecutive Director, C...      0    ...           0
#  Logan (Mehl-Laituri) Isaac, ContributorAuthor ...      0    ...           0
# #DoctorsSpeakOut, Contributor#DoctorsSpeakOut i...      0    ...           0
# 'The Koch Sisters', ContributorSo not related t...      0    ...           0
# 10,000 Small Businesses Program, ContributorAn ...      0    ...           0
# 1in20, ContributorVisual stories to destigmatiz...      0    ...           0
# 24/7 Wall St., ContributorSpecial Report                0    ...           0
# 2BoomerBabes, ContributorKathy Bernard and Barb...      0    ...           0
# 2morrowknight, ContributorBestselling Author of...      0    ...           0
# 40 Percent and Rising, ContributorLeading the P...      0    ...           0
# A View From The United Nations, ContributorSeni...      0    ...           0
# A. Ananthalakshmi, Reuters                              0    ...           0
# A. B. Wilkinson, ContributorAssistant Professor...      0    ...           0
# A. Lynn, ContributorFeminist, cinephile, and no...      0    ...           0
# A. Siegel, ContributorEnergy, Environmental Blo...      0    ...           0
# A. Townsend Peterson, ContributorUniversity Dis...      0    ...           0
# A. Trevor Thrall, ContributorSenior Fellow at t...      0    ...           0
# A.C. Thompson and Robert Faturechi, ProPublica,...      0    ...           0
# A.C. Thompson, ProPublica                               0    ...           0
# A.J. Condeelis, ContributorWriter, researcher, ...      0    ...           0
# A.J. Walkley, ContributorAuthor of Vuto & Queer...      0    ...           0
# A.T. McWilliams, Guest WriterGuest Writer               0    ...           0
# AALICIA RANCILIO, Associated Press, Associated ...      0    ...           1
# ABDOULIE JOHN, AP                                       0    ...           0
# ABDULLAH SHARIF, ContributorAuthor and Former D...      0    ...           0
# ...                                                   ...    ...         ...
# Zorianna Kit, ContributorEntertainment journali...      0    ...           1
# Zoë B, ContributorFounder of the Simple Life St...      0    ...           0
# Zoë Triska                                              0    ...           0
# Zsofi McMullin, ContributorWriter                       0    ...           0
# Zubin Sharma, ContributorFounder, Project Poten...      0    ...           0
# Zuhour Mahmoud, Syria Deeply                            0    ...           0
# a.j.k. o'donnell, Contributoraward-winning acti...      0    ...           0
# beverly iseghohi, ContributorPublic Affairs Pro...      0    ...           0
# by Luigi F. di Biagio, La Dolce Vita                    0    ...           0
# charles easley, ContributorI explore, race, cla...      0    ...           0
# davidji, Contributorglobally recognized mindbod...      0    ...           0
# hanna arc, ContributorIndependent Journalist & ...      0    ...           0
# iMFdirect, ContributoriMFdirect features views ...      0    ...           0
# ilona saari, ContributorNovelist, Essayist and ...      0    ...           0
# j.frede, ContributorMultidisciplinary artist ba...      0    ...           0
# j.n. salters, ContributorBlack feminist writer ...      0    ...           0
# justin adkins, ContributorRevolutionary trans* ...      0    ...           0
# meQuilibrium, ContributorPersonalized Stress Ma...      0    ...           0
# ngrid Melander and Sudip Kar-Gupta, Reuters             0    ...           0
# offMetro.com, ContributorGet Out of Town, Car O...      0    ...           0
# oni Clarke and Ransdell Pierson, Reuters                0    ...           0
# ric drasin, ContributorCreator, Iconic Gold's g...      0    ...           1
# simon confino, ContributorFounder Director We-Q...      0    ...           0
# trivago, ContributorHotel search site                   0    ...           0
# xoJANE, Contributor                                     0    ...           0
# xxxx, ContributorProfessor Emeritus, Department...      0    ...           0
# yd Zeigler, Outsports                                   0    ...           0
# Éloïse Bouton, ContributorFreelance journalist,...      0    ...           0
# レシピブログ通信, ContributorEveryday fun, lifestyle, a...      0    ...           0
# 딘 베이커, ContributorCo-director, CEPR; author, "R...      0    ...           0
#
# category                                            STYLE  TASTE  TECH  \
# authors
#                                                       128     56   244
#  Bill Bigelow, ContributorRethinking Schools cu...      0      0     0
#  Bustle, ContributorNews, entertainment, lifest...      0      0     0
#  Cristian Farias, Elise Foley, and Willa Frej           0      0     0
#  Jamie Walker, ContributorCEO and Founder of Sw...      0      0     0
#  Josh Horwitz, ContributorExecutive Director, C...      0      0     0
#  Logan (Mehl-Laituri) Isaac, ContributorAuthor ...      0      0     0
# #DoctorsSpeakOut, Contributor#DoctorsSpeakOut i...      0      0     0
# 'The Koch Sisters', ContributorSo not related t...      0      0     0
# 10,000 Small Businesses Program, ContributorAn ...      0      0     0
# 1in20, ContributorVisual stories to destigmatiz...      0      0     0
# 24/7 Wall St., ContributorSpecial Report                0      0     0
# 2BoomerBabes, ContributorKathy Bernard and Barb...      0      0     0
# 2morrowknight, ContributorBestselling Author of...      0      0     0
# 40 Percent and Rising, ContributorLeading the P...      0      0     0
# A View From The United Nations, ContributorSeni...      0      0     0
# A. Ananthalakshmi, Reuters                              0      0     0
# A. B. Wilkinson, ContributorAssistant Professor...      0      0     0
# A. Lynn, ContributorFeminist, cinephile, and no...      0      0     0
# A. Siegel, ContributorEnergy, Environmental Blo...      0      0     0
# A. Townsend Peterson, ContributorUniversity Dis...      0      0     0
# A. Trevor Thrall, ContributorSenior Fellow at t...      0      0     0
# A.C. Thompson and Robert Faturechi, ProPublica,...      0      0     0
# A.C. Thompson, ProPublica                               0      0     0
# A.J. Condeelis, ContributorWriter, researcher, ...      0      0     0
# A.J. Walkley, ContributorAuthor of Vuto & Queer...      0      0     0
# A.T. McWilliams, Guest WriterGuest Writer               0      0     0
# AALICIA RANCILIO, Associated Press, Associated ...      0      0     0
# ABDOULIE JOHN, AP                                       0      0     0
# ABDULLAH SHARIF, ContributorAuthor and Former D...      0      0     0
# ...                                                   ...    ...   ...
# Zorianna Kit, ContributorEntertainment journali...      8      0     0
# Zoë B, ContributorFounder of the Simple Life St...      0      0     0
# Zoë Triska                                              0      0     0
# Zsofi McMullin, ContributorWriter                       0      0     0
# Zubin Sharma, ContributorFounder, Project Poten...      0      0     0
# Zuhour Mahmoud, Syria Deeply                            0      0     0
# a.j.k. o'donnell, Contributoraward-winning acti...      0      0     0
# beverly iseghohi, ContributorPublic Affairs Pro...      0      0     0
# by Luigi F. di Biagio, La Dolce Vita                    0      0     0
# charles easley, ContributorI explore, race, cla...      0      0     0
# davidji, Contributorglobally recognized mindbod...      0      0     0
# hanna arc, ContributorIndependent Journalist & ...      0      0     0
# iMFdirect, ContributoriMFdirect features views ...      0      0     0
# ilona saari, ContributorNovelist, Essayist and ...      0      0     0
# j.frede, ContributorMultidisciplinary artist ba...      0      0     0
# j.n. salters, ContributorBlack feminist writer ...      0      0     0
# justin adkins, ContributorRevolutionary trans* ...      0      0     0
# meQuilibrium, ContributorPersonalized Stress Ma...      0      0     0
# ngrid Melander and Sudip Kar-Gupta, Reuters             0      0     0
# offMetro.com, ContributorGet Out of Town, Car O...      0      0     0
# oni Clarke and Ransdell Pierson, Reuters                0      0     0
# ric drasin, ContributorCreator, Iconic Gold's g...      0      0     0
# simon confino, ContributorFounder Director We-Q...      0      0     0
# trivago, ContributorHotel search site                   0      0     0
# xoJANE, Contributor                                     0      0     0
# xxxx, ContributorProfessor Emeritus, Department...      0      0     0
# yd Zeigler, Outsports                                   0      0     0
# Éloïse Bouton, ContributorFreelance journalist,...      0      0     0
# レシピブログ通信, ContributorEveryday fun, lifestyle, a...      0      1     0
# 딘 베이커, ContributorCo-director, CEPR; author, "R...      0      0     0
#
# category                                            THE WORLDPOST  TRAVEL  \
# authors
#                                                              1466      54
#  Bill Bigelow, ContributorRethinking Schools cu...              0       0
#  Bustle, ContributorNews, entertainment, lifest...              0       0
#  Cristian Farias, Elise Foley, and Willa Frej                   0       0
#  Jamie Walker, ContributorCEO and Founder of Sw...              0       0
#  Josh Horwitz, ContributorExecutive Director, C...              0       0
#  Logan (Mehl-Laituri) Isaac, ContributorAuthor ...              0       0
# #DoctorsSpeakOut, Contributor#DoctorsSpeakOut i...              0       0
# 'The Koch Sisters', ContributorSo not related t...              0       0
# 10,000 Small Businesses Program, ContributorAn ...              0       0
# 1in20, ContributorVisual stories to destigmatiz...              0       0
# 24/7 Wall St., ContributorSpecial Report                        0       0
# 2BoomerBabes, ContributorKathy Bernard and Barb...              0       1
# 2morrowknight, ContributorBestselling Author of...              0       0
# 40 Percent and Rising, ContributorLeading the P...              0       0
# A View From The United Nations, ContributorSeni...              1       0
# A. Ananthalakshmi, Reuters                                      1       0
# A. B. Wilkinson, ContributorAssistant Professor...              0       0
# A. Lynn, ContributorFeminist, cinephile, and no...              0       0
# A. Siegel, ContributorEnergy, Environmental Blo...              0       0
# A. Townsend Peterson, ContributorUniversity Dis...              0       0
# A. Trevor Thrall, ContributorSenior Fellow at t...              0       0
# A.C. Thompson and Robert Faturechi, ProPublica,...              0       0
# A.C. Thompson, ProPublica                                       0       0
# A.J. Condeelis, ContributorWriter, researcher, ...              0       0
# A.J. Walkley, ContributorAuthor of Vuto & Queer...              0       0
# A.T. McWilliams, Guest WriterGuest Writer                       0       0
# AALICIA RANCILIO, Associated Press, Associated ...              0       0
# ABDOULIE JOHN, AP                                               0       0
# ABDULLAH SHARIF, ContributorAuthor and Former D...              0       0
# ...                                                           ...     ...
# Zorianna Kit, ContributorEntertainment journali...              0       0
# Zoë B, ContributorFounder of the Simple Life St...              0       0
# Zoë Triska                                                      0       2
# Zsofi McMullin, ContributorWriter                               0       0
# Zubin Sharma, ContributorFounder, Project Poten...              0       0
# Zuhour Mahmoud, Syria Deeply                                    3       0
# a.j.k. o'donnell, Contributoraward-winning acti...              0       0
# beverly iseghohi, ContributorPublic Affairs Pro...              0       0
# by Luigi F. di Biagio, La Dolce Vita                            0       1
# charles easley, ContributorI explore, race, cla...              0       0
# davidji, Contributorglobally recognized mindbod...              0       0
# hanna arc, ContributorIndependent Journalist & ...              0       0
# iMFdirect, ContributoriMFdirect features views ...              0       0
# ilona saari, ContributorNovelist, Essayist and ...              0       0
# j.frede, ContributorMultidisciplinary artist ba...              0       0
# j.n. salters, ContributorBlack feminist writer ...              0       0
# justin adkins, ContributorRevolutionary trans* ...              0       0
# meQuilibrium, ContributorPersonalized Stress Ma...              0       0
# ngrid Melander and Sudip Kar-Gupta, Reuters                     1       0
# offMetro.com, ContributorGet Out of Town, Car O...              0       3
# oni Clarke and Ransdell Pierson, Reuters                        0       0
# ric drasin, ContributorCreator, Iconic Gold's g...              0       0
# simon confino, ContributorFounder Director We-Q...              0       0
# trivago, ContributorHotel search site                           0       6
# xoJANE, Contributor                                             0       0
# xxxx, ContributorProfessor Emeritus, Department...              0       0
# yd Zeigler, Outsports                                           0       0
# Éloïse Bouton, ContributorFreelance journalist,...              0       0
# レシピブログ通信, ContributorEveryday fun, lifestyle, a...              0       0
# 딘 베이커, ContributorCo-director, CEPR; author, "R...              0       0
#
# category                                            WEIRD NEWS  WOMEN  \
# authors
#                                                            386    369
#  Bill Bigelow, ContributorRethinking Schools cu...           0      0
#  Bustle, ContributorNews, entertainment, lifest...           0      1
#  Cristian Farias, Elise Foley, and Willa Frej                0      0
#  Jamie Walker, ContributorCEO and Founder of Sw...           0      0
#  Josh Horwitz, ContributorExecutive Director, C...           0      0
#  Logan (Mehl-Laituri) Isaac, ContributorAuthor ...           0      0
# #DoctorsSpeakOut, Contributor#DoctorsSpeakOut i...           0      0
# 'The Koch Sisters', ContributorSo not related t...           0      0
# 10,000 Small Businesses Program, ContributorAn ...           0      0
# 1in20, ContributorVisual stories to destigmatiz...           0      0
# 24/7 Wall St., ContributorSpecial Report                     0      0
# 2BoomerBabes, ContributorKathy Bernard and Barb...           0      0
# 2morrowknight, ContributorBestselling Author of...           0      0
# 40 Percent and Rising, ContributorLeading the P...           0      2
# A View From The United Nations, ContributorSeni...           0      0
# A. Ananthalakshmi, Reuters                                   0      0
# A. B. Wilkinson, ContributorAssistant Professor...           0      0
# A. Lynn, ContributorFeminist, cinephile, and no...           0      1
# A. Siegel, ContributorEnergy, Environmental Blo...           0      0
# A. Townsend Peterson, ContributorUniversity Dis...           0      0
# A. Trevor Thrall, ContributorSenior Fellow at t...           0      0
# A.C. Thompson and Robert Faturechi, ProPublica,...           0      0
# A.C. Thompson, ProPublica                                    0      0
# A.J. Condeelis, ContributorWriter, researcher, ...           0      0
# A.J. Walkley, ContributorAuthor of Vuto & Queer...           0      0
# A.T. McWilliams, Guest WriterGuest Writer                    0      0
# AALICIA RANCILIO, Associated Press, Associated ...           0      0
# ABDOULIE JOHN, AP                                            0      0
# ABDULLAH SHARIF, ContributorAuthor and Former D...           0      0
# ...                                                        ...    ...
# Zorianna Kit, ContributorEntertainment journali...           0      0
# Zoë B, ContributorFounder of the Simple Life St...           0      0
# Zoë Triska                                                   0      0
# Zsofi McMullin, ContributorWriter                            0      1
# Zubin Sharma, ContributorFounder, Project Poten...           0      0
# Zuhour Mahmoud, Syria Deeply                                 0      0
# a.j.k. o'donnell, Contributoraward-winning acti...           0      0
# beverly iseghohi, ContributorPublic Affairs Pro...           0      0
# by Luigi F. di Biagio, La Dolce Vita                         0      0
# charles easley, ContributorI explore, race, cla...           0      0
# davidji, Contributorglobally recognized mindbod...           0      0
# hanna arc, ContributorIndependent Journalist & ...           0      0
# iMFdirect, ContributoriMFdirect features views ...           0      0
# ilona saari, ContributorNovelist, Essayist and ...           0      0
# j.frede, ContributorMultidisciplinary artist ba...           0      0
# j.n. salters, ContributorBlack feminist writer ...           0      0
# justin adkins, ContributorRevolutionary trans* ...           0      0
# meQuilibrium, ContributorPersonalized Stress Ma...           0      0
# ngrid Melander and Sudip Kar-Gupta, Reuters                  0      0
# offMetro.com, ContributorGet Out of Town, Car O...           0      0
# oni Clarke and Ransdell Pierson, Reuters                     0      0
# ric drasin, ContributorCreator, Iconic Gold's g...           0      0
# simon confino, ContributorFounder Director We-Q...           0      0
# trivago, ContributorHotel search site                        0      0
# xoJANE, Contributor                                          0      8
# xxxx, ContributorProfessor Emeritus, Department...           0      0
# yd Zeigler, Outsports                                        0      0
# Éloïse Bouton, ContributorFreelance journalist,...           0      0
# レシピブログ通信, ContributorEveryday fun, lifestyle, a...           0      0
# 딘 베이커, ContributorCo-director, CEPR; author, "R...           0      0
#
# category                                            WORLD NEWS  WORLDPOST
# authors
#                                                            351        774
#  Bill Bigelow, ContributorRethinking Schools cu...           0          0
#  Bustle, ContributorNews, entertainment, lifest...           0          0
#  Cristian Farias, Elise Foley, and Willa Frej                0          0
#  Jamie Walker, ContributorCEO and Founder of Sw...           0          0
#  Josh Horwitz, ContributorExecutive Director, C...           0          0
#  Logan (Mehl-Laituri) Isaac, ContributorAuthor ...           0          0
# #DoctorsSpeakOut, Contributor#DoctorsSpeakOut i...           0          0
# 'The Koch Sisters', ContributorSo not related t...           0          0
# 10,000 Small Businesses Program, ContributorAn ...           0          0
# 1in20, ContributorVisual stories to destigmatiz...           0          0
# 24/7 Wall St., ContributorSpecial Report                     0          0
# 2BoomerBabes, ContributorKathy Bernard and Barb...           0          0
# 2morrowknight, ContributorBestselling Author of...           0          0
# 40 Percent and Rising, ContributorLeading the P...           0          0
# A View From The United Nations, ContributorSeni...           2          0
# A. Ananthalakshmi, Reuters                                   0          0
# A. B. Wilkinson, ContributorAssistant Professor...           0          0
# A. Lynn, ContributorFeminist, cinephile, and no...           0          0
# A. Siegel, ContributorEnergy, Environmental Blo...           0          0
# A. Townsend Peterson, ContributorUniversity Dis...           0          0
# A. Trevor Thrall, ContributorSenior Fellow at t...           0          0
# A.C. Thompson and Robert Faturechi, ProPublica,...           0          0
# A.C. Thompson, ProPublica                                    0          0
# A.J. Condeelis, ContributorWriter, researcher, ...           0          0
# A.J. Walkley, ContributorAuthor of Vuto & Queer...           0          0
# A.T. McWilliams, Guest WriterGuest Writer                    0          0
# AALICIA RANCILIO, Associated Press, Associated ...           0          0
# ABDOULIE JOHN, AP                                            0          0
# ABDULLAH SHARIF, ContributorAuthor and Former D...           0          0
# ...                                                        ...        ...
# Zorianna Kit, ContributorEntertainment journali...           0          0
# Zoë B, ContributorFounder of the Simple Life St...           0          0
# Zoë Triska                                                   0          1
# Zsofi McMullin, ContributorWriter                            0          0
# Zubin Sharma, ContributorFounder, Project Poten...           0          0
# Zuhour Mahmoud, Syria Deeply                                 0          0
# a.j.k. o'donnell, Contributoraward-winning acti...           0          0
# beverly iseghohi, ContributorPublic Affairs Pro...           0          0
# by Luigi F. di Biagio, La Dolce Vita                         0          0
# charles easley, ContributorI explore, race, cla...           0          0
# davidji, Contributorglobally recognized mindbod...           0          0
# hanna arc, ContributorIndependent Journalist & ...           0          0
# iMFdirect, ContributoriMFdirect features views ...           0          1
# ilona saari, ContributorNovelist, Essayist and ...           0          0
# j.frede, ContributorMultidisciplinary artist ba...           0          0
# j.n. salters, ContributorBlack feminist writer ...           0          0
# justin adkins, ContributorRevolutionary trans* ...           0          0
# meQuilibrium, ContributorPersonalized Stress Ma...           0          0
# ngrid Melander and Sudip Kar-Gupta, Reuters                  0          0
# offMetro.com, ContributorGet Out of Town, Car O...           0          0
# oni Clarke and Ransdell Pierson, Reuters                     0          0
# ric drasin, ContributorCreator, Iconic Gold's g...           0          0
# simon confino, ContributorFounder Director We-Q...           0          0
# trivago, ContributorHotel search site                        0          0
# xoJANE, Contributor                                          0          0
# xxxx, ContributorProfessor Emeritus, Department...           0          0
# yd Zeigler, Outsports                                        0          0
# Éloïse Bouton, ContributorFreelance journalist,...           0          1
# レシピブログ通信, ContributorEveryday fun, lifestyle, a...           0          0
# 딘 베이커, ContributorCo-director, CEPR; author, "R...           0          0
#
# [19250 rows x 31 columns]

# %%
# Drop author name also
dataset.drop(['authors'], axis=1, inplace=True)

# %%
dataset.shape
# Out:
# (124989, 3)

# %% [markdown]
# ##### 2.3 Process and split dataset

# %%
# Merge headline and description into one to make data eligible for Naive Bayes Classification
dataset['text'] = dataset['headline'] + '. ' + dataset['short_description']
dataset.drop(['headline', 'short_description'], axis=1, inplace=True)

# %%
# Convert text to lowercase
dataset['text'] = dataset['text'].str.lower()

# %%
# Convert class names to integer values
le = preprocessing.LabelEncoder()
le.fit(dataset['category'])
x_dataset = dataset['text']
y_dataset = le.transform(dataset['category'])

# %%
train_dataset, valid_dataset, train_labels, valid_labels = model_selection.train_test_split(x_dataset, y_dataset)

# %% [markdown]
# ### 3. Feature creation
# ##### TF-IDF Vector

# %%
"""
    We use TF-IDF because it has been found to give the best results for multiclass text classification systems.
    
    It calculates the term frequency (number of times word occurs in a document) and inverse document
    frequency (amount of information conveyed by the word)
"""
tfidf_vect = TfidfVectorizer(analyzer='word', token_pattern='\w{1,}', max_features=5000)
tfidf_vect.fit(x_dataset)

train_tfidf = tfidf_vect.transform(train_dataset)
valid_tfidf = tfidf_vect.transform(valid_dataset)

# %% [markdown]
# ### 4. Building a model

# %%
def train_model(classifier, training_vector, training_labels, valid_vector, valid_labels):
    classifier.fit(training_vector, training_labels)
    
    predictions = classifier.predict(valid_vector)
    
    return metrics.accuracy_score(predictions, valid_labels), classifier

# %% [markdown]
# ### 4.1 Naive Bayes Classifier
# A simple classifier that gives excellent results in text classification models

# %%
accuracy, _ = train_model(naive_bayes.MultinomialNB(), train_tfidf, train_labels, valid_tfidf, valid_labels)
print("Naive Bayes accuracy:", accuracy)
# Out:
# Naive Bayes accuracy: 0.5003520225294419

# %% [markdown]
# ### 4.2 Logistic Regression
# Another simple classifier prone to overfitting

# %%
accuracy, classifier = train_model(linear_model.LogisticRegression(multi_class='ovr'), train_tfidf, train_labels, valid_tfidf, valid_labels)
print("Logistic Regression accuracy:", accuracy)
# Out:
# Logistic Regression accuracy: 0.5811891961085509

# %% [markdown]
# ### 4.3 Support Vector Machine with online learning

# %%
accuracy = train_model(linear_model.SGDClassifier(loss='hinge', penalty='l2', max_iter=10), train_tfidf, train_labels, valid_tfidf, valid_labels)
print("Support Vector Machine with online learning:", accuracy)
# Out:
# Support Vector Machine with online learning: 0.5613799283154122

# %% [markdown]
# ### 5 Actual work
# Since logistic regression gives the best accuracy, we'll use this model to classify

# %% [markdown]
# ##### 5.1 Actual example of prediction

# %%
sample_input = dataset.loc[0]

# %%
print("Input:", sample_input['text'])
print("Class:", sample_input['category'])
# Out:
# Input: there were 2 mass shootings in texas last week, but only 1 on tv. she left her husband. he killed their children. just another day in america.
# Class: CRIME

# %%
print("Classifier output:", le.inverse_transform(classifier.predict(tfidf_vect.transform([sample_input['text']])))[0])
# Out:
# Classifier output: CRIME
